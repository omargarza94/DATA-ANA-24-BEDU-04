# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Crear un diccionario con los datos
data = {
    'Nivel_de_estres': [7, 6, 8, 5, 9, 4, 7, 3, 10, 2],
    'Horas_de_sueño': [5, 6, 4, 7, 3, 8, 5, 9, 2, 10],
    'Horas_de_ejercicio': [1, 2, 1, 3, 0, 4, 1, 3, 0, 5]
}

# Crear un DataFrame con los datos
df = pd.DataFrame(data)

# Mostrar el DataFrame
df.head()
# Out:
#    Nivel_de_estres  Horas_de_sueño  Horas_de_ejercicio
# 0                7               5                   1
# 1                6               6                   2
# 2                8               4                   1
# 3                5               7                   3
# 4                9               3                   0

# %% [markdown]
# ### Visualizacion

# %%
# Creacion de un pairplot
sns.pairplot(df)

# Personalización
plt.suptitle('Pairplot')
plt.show()

# %% [markdown]
# ### Sacando el titulo de enmedio

# %%
# Creacion de un pairplot
sns.pairplot(df)

# Personalización
plt.suptitle('Pairplot', y=1.02)
plt.show()
